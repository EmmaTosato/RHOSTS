# %%
import pandas
import numpy as np
import nibabel as nib

# %%
sub1_input = "/data/etosato/RHOSTS/Input/subject1_left.txt"
sub_our = "/data/etosato/RHOSTS/Input/134829.nii.gz"

# %%
import os
os.getcwd()
# Out:
# '/data/etosato/RHOSTS/Notebooks'

# %% [markdown]
# # Input

# %% [markdown]
# ## HCP subject

# %% [markdown]
# One subject example taken from Human Connectome Project

# %% [markdown]
# - 119 rows: Representing 119 brain regions of interest (ROIs).
#
# - 1200 columns: Representing time points or temporal samples.

# %%
np.loadtxt(sub1_input).shape
# Out:
# (1200, 119)

# %% [markdown]
# ## Lorenzo's sample

# %%
# Load file .nii.gz
nii = nib.load(sub_our)
data = nii.get_fdata()
# Out:
# ---------------------------------------------------------------------------
# ImageFileError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Load file .nii.gz
# ----> 2 nii = nib.load(sub_our)
#
# File ~/miniconda3/envs/rhosts/lib/python3.8/site-packages/nibabel/loadsave.py:104, in load(filename, **kwargs)
#     102     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     103 if stat_result.st_size <= 0:
# --> 104     raise ImageFileError(f"Empty file: '{filename}'")
#     106 sniff = None
#     107 for image_klass in all_image_classes:
#
# ImageFileError: Empty file: '/data/etosato/RHOSTS/Input/134829.nii.gz'

# %%
# Riorganizza i dati: ogni riga = un timepoint, ogni colonna = un voxel
n_voxels = np.prod(data.shape[:-1])
n_timepoints = data.shape[-1]

# Trasforma in matrice 2D (T x n_voxels)
data_2d = data.reshape(-1, n_timepoints).T  # ora shape = (T, n_voxels)

# Salva in txt
np.savetxt("output_timeseries.txt", data_2d, fmt="%.6f")
